# %%
class Student_Mangement_System:
  def __init__(self,name,age,roll_no):
    self.name = name
    self.age = age
    self.roll_no = roll_no
    self.grade = ""

  def enroll_course(self,new_course):
    print("You enrolled on new course named: ", new_course)

  def change_grade(self,new_grade):
    self.grade = new_grade

  def view_grade(self):
    print("Your grade is ",self.grade)

Rayyan = Student_Mangement_System("Rayyan",12,1325)
Rayyan.enroll_course("python Machine learning")
Rayyan.change_grade("A")
Rayyan.view_grade()
# Out:
# You enrolled on new course named:  python Machine learning
# Your grade is  A

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/content/Superstore_upd.csv")
data
# Out:
#       Row ID        Country       State Region         Category Sub-Category  \
# 0          1  United States    Kentucky  South        Furniture    Bookcases
# 1          2  United States    Kentucky  South        Furniture       Chairs
# 2          3  United States  California   West  Office Supplies       Labels
# 3          4  United States     Florida  South        Furniture       Tables
# 4          5  United States     Florida  South  Office Supplies      Storage
# ...      ...            ...         ...    ...              ...          ...
# 9989    9990  United States     Florida  South        Furniture  Furnishings
# 9990    9991  United States  California   West        Furniture  Furnishings
# 9991    9992  United States  California   West       Technology       Phones
# 9992    9993  United States  California   West  Office Supplies        Paper
# 9993    9994  United States  California   West  Office Supplies   Appliances
#
#          Sales  Quantity  Discount    Profit
# 0     261.9600         2      0.00   41.9136
# 1     731.9400         3      0.00  219.5820
# 2      14.6200         2      0.00    6.8714
# 3     957.5775         5      0.45 -383.0310
# 4      22.3680         2      0.20    2.5164
# ...        ...       ...       ...       ...
# 9989   25.2480         3      0.20    4.1028
# 9990   91.9600         2      0.00   15.6332
# 9991  258.5760         2      0.20   19.3932
# 9992   29.6000         4      0.00   13.3200
# 9993  243.1600         2      0.00   72.9480
#
# [9994 rows x 10 columns]

# %%
data.describe()
# Out:
#             Row ID         Sales     Quantity     Discount       Profit
# count  9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   4997.500000    229.858001     3.789574     0.156203    28.656896
# std    2885.163629    623.245101     2.225110     0.206452   234.260108
# min       1.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    2499.250000     17.280000     2.000000     0.000000     1.728750
# 50%    4997.500000     54.490000     3.000000     0.200000     8.666500
# 75%    7495.750000    209.940000     5.000000     0.200000    29.364000
# max    9994.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
data.isnull()
# Out:
#       Row ID  Country  State  Region  Category  Sub-Category  Sales  Quantity  \
# 0      False    False  False   False     False         False  False     False
# 1      False    False  False   False     False         False  False     False
# 2      False    False  False   False     False         False  False     False
# 3      False    False  False   False     False         False  False     False
# 4      False    False  False   False     False         False  False     False
# ...      ...      ...    ...     ...       ...           ...    ...       ...
# 9989   False    False  False   False     False         False  False     False
# 9990   False    False  False   False     False         False  False     False
# 9991   False    False  False   False     False         False  False     False
# 9992   False    False  False   False     False         False  False     False
# 9993   False    False  False   False     False         False  False     False
#
#       Discount  Profit
# 0        False   False
# 1        False   False
# 2        False   False
# 3        False   False
# 4        False   False
# ...        ...     ...
# 9989     False   False
# 9990     False   False
# 9991     False   False
# 9992     False   False
# 9993     False   False
#
# [9994 rows x 10 columns]

# %%
data.median()
# Out:
# <ipython-input-4-135339ac59ce>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.median()
# Row ID      4997.5000
# Sales         54.4900
# Quantity       3.0000
# Discount       0.2000
# Profit         8.6665
# dtype: float64

# %%
data.mode()
# Out:
#       Row ID        Country       State Region         Category Sub-Category  \
# 0          1  United States  California   West  Office Supplies      Binders
# 1          2            NaN         NaN    NaN              NaN          NaN
# 2          3            NaN         NaN    NaN              NaN          NaN
# 3          4            NaN         NaN    NaN              NaN          NaN
# 4          5            NaN         NaN    NaN              NaN          NaN
# ...      ...            ...         ...    ...              ...          ...
# 9989    9990            NaN         NaN    NaN              NaN          NaN
# 9990    9991            NaN         NaN    NaN              NaN          NaN
# 9991    9992            NaN         NaN    NaN              NaN          NaN
# 9992    9993            NaN         NaN    NaN              NaN          NaN
# 9993    9994            NaN         NaN    NaN              NaN          NaN
#
#       Sales  Quantity  Discount  Profit
# 0     12.96       3.0       0.0     0.0
# 1       NaN       NaN       NaN     NaN
# 2       NaN       NaN       NaN     NaN
# 3       NaN       NaN       NaN     NaN
# 4       NaN       NaN       NaN     NaN
# ...     ...       ...       ...     ...
# 9989    NaN       NaN       NaN     NaN
# 9990    NaN       NaN       NaN     NaN
# 9991    NaN       NaN       NaN     NaN
# 9992    NaN       NaN       NaN     NaN
# 9993    NaN       NaN       NaN     NaN
#
# [9994 rows x 10 columns]

# %%
data.mean()
# Out:
# <ipython-input-6-abc01cf6c622>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.mean()
# Row ID      4997.500000
# Sales        229.858001
# Quantity       3.789574
# Discount       0.156203
# Profit        28.656896
# dtype: float64

# %%
data2 = data.head(20)
data2.plot(y = "Quantity" , x = "Category")
# Out:
# <Axes: xlabel='Category'>

# %%
data2.plot.bar(y = "Quantity" , x = "Category")
# Out:
# <Axes: xlabel='Category'>

# %%
data2.plot.barh(y = "Quantity" , x = "Category")
# Out:
# <Axes: ylabel='Category'>

# %%
data2.plot.scatter(y = "Quantity" , x = "Category")
# Out:
# <Axes: xlabel='Category', ylabel='Quantity'>

# %%
data2.plot.box(y = "Quantity" , x = "Category")
# Out:
# <Axes: >
